# %%
## Import block
# %matplotlib inline

import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d 
import seaborn as sns; sns.set()

import numpy as np
from numpy import linalg as LA
import pandas as pd

from sklearn import linear_model

# %%
myst = np.random.normal(0,2,300)
mysty = 300 + 10*np.random.normal(0,3,300) + 2*myst - 5*myst**2 + (1/4)*myst**3

# %%
plt.scatter(myst,mysty)

# %%
myst2 = myst**2

# %%
myst3 = myst**3
myst4 = myst**4
myst5 = myst**5
myst6 = myst**6
myst7 = myst**7
myst8 = myst**8
myst9 = myst**9
myst10 = myst**10

# %%
mystery = {
    "mysty": mysty,
    "myst": myst, "myst2": myst2,
    "myst3": myst3, "myst4": myst4,
    "myst5": myst5, "myst6": myst6,
    "myst7": myst7, "myst8": myst8,
    "myst9": myst9, "myst10": myst10,
}
cols = ["mysty","myst","myst2","myst3","myst4","myst5","myst6","myst7","myst8","myst9","myst10"]
mystery_data = pd.DataFrame(mystery, 
                            columns = cols)

# %%
mystery_data
# Out:
#           mysty      myst      myst2       myst3        myst4        myst5  \
# 0    317.517233 -0.622626   0.387664   -0.241370     0.150283    -0.093570
# 1    234.079678 -1.792505   3.213075   -5.759453    10.323849   -18.505553
# 2    240.189920 -1.534783   2.355559   -3.615272     5.548658    -8.515986
# 3    296.233620 -0.324150   0.105073   -0.034059     0.011040    -0.003579
# 4    260.674765 -0.864538   0.747425   -0.646177     0.558644    -0.482969
# ..          ...       ...        ...         ...          ...          ...
# 295    2.577875 -6.059637  36.719198 -222.505003  1348.299499 -8170.205240
# 296  245.308181 -2.286556   5.228340  -11.954894    27.335539   -62.504251
# 297  281.890530  0.399711   0.159769    0.063861     0.025526     0.010203
# 298  277.111896  1.279136   1.636189    2.092908     2.677114     3.424393
# 299  253.374408 -0.621649   0.386447   -0.240234     0.149341    -0.092838
#
# ...

# %%
mystery_data.to_csv("lab12data.csv", index=False)
